# %% [markdown]
# # First Order Logic with Tensors
#
# This is an implemetation of [Towards a Formal Distributional Semantics: Simulating Logical Calculi with Tensors](https://arxiv.org/pdf/1304.5823.pdf) (Grefenstette, 2013) using `python` and `numpy`.
#
# **New Feature:** This notebook now demonstrates both **Dense** and **Sparse** vector representations.

# %%
import LogicModel as m
import numpy as np

# %% [markdown]
# ## 1. Dense Representation Demonstration

# %%
my_domain = [
    "john", 
    "chris", 
    "tom", 
    "mary", 
    "bill"
]

my_unary_preds = {
    "is_mathematician": ["john", "chris"],
    "is_single": ["bill"]
}

my_binary_preds = {
    "hates": [("tom", "chris"), ("tom", "john"), ("chris", "chris")],
    "loves": [("mary", "john"), ("john", "john"), ("mary", "mary")]
}

# Initialize LogicModel (Default is dense)
dense_model = m.LogicModel(
    listOfElements=my_domain,
    dictionaryOfUnaryPredicates=my_unary_preds,
    dictionaryOfBinaryPredicates=my_binary_preds,
    use_sparse=False
)
dense_model.buildAll()

# %% [markdown]
# ### Queries (Dense)

# %%
print("Tom is mathematician (Dense):", dense_model.unaryOp("is_mathematician", "tom").flatten())
print("Mary loves John (Dense):", dense_model.binaryOp("loves", "mary", "john").flatten())
print("Mary loves Chris (Dense):", dense_model.binaryOp("loves", "mary", "chris").flatten())
# Out:
# Tom is mathematician (Dense): [0. 1.]
# Mary loves John (Dense): [1. 0.]
# Mary loves Chris (Dense): [0. 1.]

# %% [markdown]
# ## 2. Sparse Representation Demonstration
#
# Now we initialize the model with `use_sparse=True`. This uses `scipy.sparse` matrices internally.

# %%
sparse_model = m.LogicModel(
    listOfElements=my_domain,
    dictionaryOfUnaryPredicates=my_unary_preds,
    dictionaryOfBinaryPredicates=my_binary_preds,
    use_sparse=True
)
sparse_model.buildAll()

# %% [markdown]
# ### Queries (Sparse)
# The results should be identical to the dense model.

# %%
print("Tom is mathematician (Sparse):", sparse_model.unaryOp("is_mathematician", "tom").flatten())
print("Mary loves John (Sparse):", sparse_model.binaryOp("loves", "mary", "john").flatten())
print("Mary loves Chris (Sparse):", sparse_model.binaryOp("loves", "mary", "chris").flatten())
# Out:
# Tom is mathematician (Sparse): [0. 1.]
# Mary loves John (Sparse): [1. 0.]
# Mary loves Chris (Sparse): [0. 1.]

# %% [markdown]
# ## 3. Dynamic Updates (Sparse & Probabilistic)
#
# We can add elements and update probabilities in the sparse model just as we did in the dense one.

# %%
new_element_tuple = (
    "dave", 
    [
        "is_mathematician",                    # Unary predicate
        ("loves", "mary", "subject"),          # Binary: dave loves mary
    ]
)

sparse_model.addToDomain(new_element_tuple)

print(f"Added 'dave'. Domain Size: {sparse_model.sizeOfDomain}")
print("Dave is mathematician (Sparse):", sparse_model.unaryOp("is_mathematician", "dave").flatten())
print("Dave loves Mary (Sparse):", sparse_model.binaryOp("loves", "dave", "mary").flatten())
# Check implicitly false fact
print("Mary loves Dave (Sparse):", sparse_model.binaryOp("loves", "mary", "dave").flatten())
# Out:
# Added 'dave'. Domain Size: 6
# Dave is mathematician (Sparse): [1. 0.]
# Dave loves Mary (Sparse): [1. 0.]
# Mary loves Dave (Sparse): [0. 1.]

# %%
# Probabilistic Unary Predicate
prob_unary_preds = {
    "is_happy": [("dave", 0.9), ("mary", 0.5)]
}
sparse_model.addUnaryPredicate("is_happy", prob_unary_preds["is_happy"])

print("Dave is happy (0.9):", sparse_model.unaryOp("is_happy", "dave").flatten())
print("Mary is happy (0.5):", sparse_model.unaryOp("is_happy", "mary").flatten())
# Out:
# Dave is happy (0.9): [0.9 0.1]
# Mary is happy (0.5): [0.5 0.5]
